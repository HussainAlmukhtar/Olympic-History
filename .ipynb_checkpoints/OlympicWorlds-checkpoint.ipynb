# %% [markdown]
# # Olympic Worlds
# ---

# %% [markdown]
# Olympians
#
# Team members:
# - Salman Bader Al-Haddad
# - Sayed Hussain Asaad Almukhtar

# %% [markdown]
# ## Introduction
# __Introduction to the topic__
#
# The Olympic Games began in ancient Greece as contests of strength and honor. Over centuries, they grew from local traditions into today’s global event, uniting nations through sport.
#
# Since the first modern Games in Athens 1896, the Olympics have expanded to include thousands of athletes, hundreds of disciplines, and both Summer and Winter editions.
#
# Beyond competition, the Olympics carry cultural and economic weight: winning medals boosts national pride, strengthens global reputation, and justifies investment in sports development. This makes them a vital priority for countries aiming to build both athletic and social success.
#
# ---

# %% [markdown]
# ## Problem Statement
#
#     The Bahrain Olympic Committee is seeking data-driven insights to guide investment in future sports facilities and programs. Using historical Olympic data on athletes, demographics, and medal achievements, this project aims to identify which sports are most aligned with Bahrain’s regional and cultural context, as well as underserved sports where targeted investments (e.g., swimming pools, basketball courts, training facilities) could maximize Bahrain’s chances of success in upcoming Olympic Games.

# %% [markdown]
# ## Objectives:
# __Questions that will guide the analysis to solve the problem__
#
#     ...
#
# ---

# %% [markdown]
# ## Exploratory Data Analysis (EDA):

# %% [markdown]
# ### Data Info:
# __Getting the data and exploring it (includes descriptive statistics)__

# %% [markdown]
# #### Sayed Hussain

# %%
# import data manupilation modules
import pandas as pd
import numpy as np
import csv

# import libraries for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Now we will define the data path
olympic_events_path = 'Data//athlete_events.csv'
olympic_regions_path = 'Data//noc_regions.csv'

#Loading The Files
olympic_events_df = pd.read_csv(olympic_events_path)
olympic_regions_df = pd.read_csv(olympic_regions_path)

display(olympic_events_df.head())
display(olympic_regions_df.head())
# Out:
#    ID                      Name     Sex   Age   Height  Weight  \
# 0   1                 A Dijiang    male  24.0  180.0cm  80.0kg
# 1   2                  A Lamusi    Male  23.0  170.0cm  60.0kg
# 2   3       Gunnar Nielsen Aaby    Male  24.0      NaN     NaN
# 3   4      Edgar Lindenau Aabye       M  34.0      NaN     NaN
# 4   5  Christine Jacoba Aaftink  FeMale  21.0  185.0cm  82.0kg
#
#              Team  NOC        Games       City          Sport  \
# 0           China  CHN  1992 Summer  Barcelona     Basketball
# 1           China  CHN  2012 Summer     London           Judo
# 2         Denmark  DEN  1920 Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900 Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988 Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
#Let us now check the data types

print("orders_df dtypes:\n", olympic_events_df.dtypes, "\n")
print("customers_df dtypes:\n", olympic_regions_df.dtypes, "\n")
# Out:
# orders_df dtypes:
#  ID          int64
# Name       object
# Sex        object
# Age       float64
# Height     object
# Weight     object
# Team       object
# NOC        object
# Games      object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object
#
# customers_df dtypes:
#  NOC       object
# region    object
# notes     object
# dtype: object

# %%
#Now we want to transform the height into a number so we removed the String
olympic_events_df['Height'] = olympic_events_df['Height'].str.replace('cm', '')

# %%
#We can Check here
olympic_events_df['Height']
# Out:
# 0         180.0
# 1         170.0
# 2           NaN
# 3           NaN
# 4         185.0
#           ...
# 271111    179.0
# 271112    176.0
# 271113    176.0
# 271114    185.0
# 271115    185.0
# Name: Height, Length: 271116, dtype: object

# %%
#Now we do the same for weight
olympic_events_df['Weight'] = olympic_events_df['Weight'].str.replace('kg', '')
olympic_events_df['Weight']
# Out:
# 0         80.0
# 1         60.0
# 2          NaN
# 3          NaN
# 4         82.0
#           ...
# 271111    89.0
# 271112    59.0
# 271113    59.0
# 271114    96.0
# 271115    96.0
# Name: Weight, Length: 271116, dtype: object

# %%
#Now we are transforming the datatypes
olympic_events_df['Height'] = olympic_events_df['Height'].astype(float)
olympic_events_df['Weight'] = olympic_events_df['Weight'].astype(float)

# %%
#Let us test the changes

print("orders_df dtypes:\n", olympic_events_df.dtypes, "\n")
print("customers_df dtypes:\n", olympic_regions_df.dtypes, "\n")
# Out:
# orders_df dtypes:
#  ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object
#
# customers_df dtypes:
#  NOC       object
# region    object
# notes     object
# dtype: object

# %%
#Now we will have a quick look at the info of our data
olympic_events_df.describe()
# Out:
#                   ID            Age         Height         Weight
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000

# %%
#Let us count the nulls
olympic_events_df.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
#Let us have a look for those people with no height
no_height = olympic_events_df[olympic_events_df['Height'].isnull()]
no_height
# Out:
#             ID                             Name   Sex   Age  Height  Weight  \
# 2            3              Gunnar Nielsen Aaby  Male  24.0     NaN     NaN
# 3            4             Edgar Lindenau Aabye     M  34.0     NaN     NaN
# 29          10   Einar Ferdinand "Einari" Aalto  male  26.0     NaN     NaN
# 35          15             Arvo Ossian Aaltonen  male  22.0     NaN     NaN
# 36          15             Arvo Ossian Aaltonen  Male  22.0     NaN     NaN
# ...        ...                              ...   ...   ...     ...     ...
# 271038  135539            Marius Edmund Zwiller  male  18.0     NaN     NaN
# 271042  135542                   Werner Zwingli  Male  29.0     NaN     NaN
# 271043  135542                   Werner Zwingli  male  29.0     NaN     NaN
# 271075  135552  Jan (Johann-) Zybert (Siebert-)  male  20.0     NaN     NaN
# 271100  135561                    Frantiek Zyka  male  26.0     NaN     NaN
#
#                   Team  NOC        Games               City  \
# 2              Denmark  DEN  1920 Summer          Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer              Paris
# 29             Finland  FIN  1952 Summer           Helsinki
# 35             Finland  FIN  1912 Summer          Stockholm
# 36             Finland  FIN  1912 Summer          Stockholm
# ...                ...  ...          ...                ...
# 271038          France  FRA  1924 Summer              Paris
# 271042     Switzerland  SUI  1956 Winter  Cortina d'Ampezzo
# 271043     Switzerland  SUI  1956 Winter  Cortina d'Ampezzo
# 271075          Poland  POL  1928 Summer          Amsterdam
# 271100  Czechoslovakia  TCH  1928 Summer          Amsterdam
#
#                        Sport  \
# 2                   Football
# 3                 Tug-Of-War
# 29                  Swimming
# 35                  Swimming
# 36                  Swimming
# ...                      ...
# 271038              Swimming
# 271042  Cross Country Skiing
# 271043  Cross Country Skiing
# 271075               Cycling
# 271100             Athletics
#
#                                                     Event Medal
# 2                                 Football Men's Football   NaN
# 3                             Tug-Of-War Men's Tug-Of-War  Gold
# 29                    Swimming Men's 400 metres Freestyle   NaN
# 35                 Swimming Men's 200 metres Breaststroke   NaN
# 36                 Swimming Men's 400 metres Breaststroke   NaN
# ...                                                   ...   ...
# 271038             Swimming Men's 200 metres Breaststroke   NaN
# 271042           Cross Country Skiing Men's 15 kilometres   NaN
# 271043  Cross Country Skiing Men's 4 x 10 kilometres R...   NaN
# 271075           Cycling Men's Team Pursuit, 4,000 metres   NaN
# 271100                           Athletics Men's Marathon   NaN
#
# [60171 rows x 13 columns]

# %%
#We notice that some of the participants have duplicateds, maybe the first entry with their ID has thier weight and height? let us check for number 15

participant_15 = olympic_events_df[olympic_events_df['ID'] == 15]
participant_15
# Out:
#     ID                  Name   Sex   Age  Height  Weight     Team  NOC  \
# 35  15  Arvo Ossian Aaltonen  male  22.0     NaN     NaN  Finland  FIN
# 36  15  Arvo Ossian Aaltonen  Male  22.0     NaN     NaN  Finland  FIN
# 37  15  Arvo Ossian Aaltonen  male  30.0     NaN     NaN  Finland  FIN
# 38  15  Arvo Ossian Aaltonen     M  30.0     NaN     NaN  Finland  FIN
# 39  15  Arvo Ossian Aaltonen     M  34.0     NaN     NaN  Finland  FIN
#
#           Games       City     Sport                                   Event  \
# 35  1912 Summer  Stockholm  Swimming  Swimming Men's 200 metres Breaststroke
# 36  1912 Summer  Stockholm  Swimming  Swimming Men's 400 metres Breaststroke
# 37  1920 Summer  Antwerpen  Swimming  Swimming Men's 200 metres Breaststroke
# 38  1920 Summer  Antwerpen  Swimming  Swimming Men's 400 metres Breaststroke
# 39  1924 Summer      Paris  Swimming  Swimming Men's 200 metres Breaststroke
#
#      Medal
# 35     NaN
# 36     NaN
# 37  Bronze
# 38  Bronze
# 39     NaN

# %%
#We Can still see no results, let us try another particiapnt for example 135542

participant_135542 = olympic_events_df[olympic_events_df['ID'] == 135542]
participant_135542
# Out:
#             ID            Name   Sex   Age  Height  Weight         Team  NOC  \
# 271042  135542  Werner Zwingli  Male  29.0     NaN     NaN  Switzerland  SUI
# 271043  135542  Werner Zwingli  male  29.0     NaN     NaN  Switzerland  SUI
#
#               Games               City                 Sport  \
# 271042  1956 Winter  Cortina d'Ampezzo  Cross Country Skiing
# 271043  1956 Winter  Cortina d'Ampezzo  Cross Country Skiing
#
#                                                     Event Medal
# 271042           Cross Country Skiing Men's 15 kilometres   NaN
# 271043  Cross Country Skiing Men's 4 x 10 kilometres R...   NaN

# %%
#Still no data...

# %% [markdown]
# #### Salman

# %% [markdown]
# ### Data Handling:
# __Cleaning, transforming, and combining data__

# %% [markdown]
# #### Sayed Hussain

# %%
#We did some essential cleaning above but here let us focus, we want to first split the games column into year and season.

# %% [markdown]
# #### Salman

# %% [markdown]
# ### Analysis:
# __Answering the objectives through data analysis__

# %% [markdown]
# #### Sayed Hussain

# %% [markdown]
# #### Salman

# %% [markdown]
# ---

# %% [markdown]
# ## Summary
# __Summarizing the key insights from the analysis__
#
# **Note**: _Use Bullet Points_
#
#     ...

# %% [markdown]
# ## Recommendations/Conclusion
# **Note**: _Use Bullet Points_
#
#     ...
